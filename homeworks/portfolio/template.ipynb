# %% [markdown]
# # Your Title Here
#
# **Name(s)**: (your name(s) here)
#
# **Website Link**: (your website link)

# %%
import pandas as pd
import numpy as np

import plotly.express as px
pd.options.plotting.backend = 'plotly'

# from lec_utils import * # Feel free to uncomment and use this. It'll make your plotly graphs look like ours in lecture!

# %% [markdown]
# ## Step 1: Introduction

# %%
# TODO
df = pd.read_csv('/Users/macbook/Desktop/EECS389/fa24/ICPSR_39172/DS0002/39172-0002-Data.tsv', sep='\t')
df
# Out:
#       RESPONDENT_ID    V1  V3  V545  V548  V549  V550  RANDOM_GROUP  \
# 0             10001  2023   1     3     4     1     1             2
# 1             10002  2023   1     3     4     1     1             2
# 2             10003  2023   1     3     4     1     1             1
# 3             10004  2023   1     3     4     1     1             2
# 4             10005  2023   1     3     4     1     1             1
# ...             ...   ...  ..   ...   ...   ...   ...           ...
# 1251          11284  2023   1     3     4     1     1             2
# 1252          11285  2023   1     3     4     1     1             1
# 1253          11286  2023   1     3     4     1     1             1
# 1254          11287  2023   1     3     4     1     1             2
# 1255          11288  2023   1     3     4     1     1             2
#
#       ARCHIVE_WT  V13  ...  V1797  V1798  V1799  V1800  V1801  V1802  V1803  \
# 0       0.753159    3  ...     -9     -9     -9     -9     -9     -9     -9
# 1       0.759757    3  ...      3      3      3      3      1      2      3
# 2       0.729394    3  ...      3      3      3      3      3      3      3
# 3       0.673155    3  ...      3      2      3      3      1      2      3
# 4       0.772525    3  ...      3      3      3      3      1      2      3
# ...          ...  ...  ...    ...    ...    ...    ...    ...    ...    ...
# 1251    0.402391    3  ...      3      3      3      3      3      3      3
# 1252    0.429136    3  ...      3      3      3      3      1      3      3
# 1253    0.434708    3  ...      3      1      3      3      1      2      3
# 1254    0.402043    3  ...      1      1      1      1      1      1      1
# 1255    0.410980    3  ...      3      3      3      3      1      2      3
#
#       V1804  V1972  V1973
# 0        -9     -9     -9
# 1         1      3      3
# 2         3      3      3
# 3         2      2      3
# 4         2      2      2
# ...     ...    ...    ...
# 1251      3      3      3
# 1252      3      2      3
# 1253      2      1      1
# 1254      1      1      1
# 1255      3      3      3
#
# [1256 rows x 630 columns]

# %% [markdown]
# ## Step 2: Data Cleaning and Exploratory Data Analysis

# %%
# TODO

# %%
# TODO

# %% [markdown]
# ## Step 3: Framing a Prediction Problem

# %%
# TODO

# %% [markdown]
# ## Step 4: Baseline Model

# %%
# TODO

# %% [markdown]
# ## Step 5: Final Model

# %%
# TODO
